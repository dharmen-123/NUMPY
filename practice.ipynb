# %%
import numpy as np

# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

r=np.corrcoef(x,y)[0,0]
print("Pearson Correlation Coefficient: ",r)
# Out:
# Pearson Correlation Coefficient:  0.9999999999999999
